# %% [markdown]
# # Module 4: Applying 1st and Higher Order Markov Chains
# ## LA Lakers Game Stats

# %% [markdown]
# Name:
# Date:

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import random

# %% [markdown]
# ### functions you'll need.

# %%
# function to pick between two states, given their mutual probabilities

def pick_state(var_a, prob_a, var_b, prob_b):

    # Validate input probabilities
    if not (0 <= prob_a <= 1 and 0 <= prob_b <= 1):
        raise ValueError("Input probabilities must be between 0 and 1")

    # Calculate the cumulative probabilities
    cum_prob_a = prob_a
    cum_prob_b = prob_a + prob_b

    # Generate a random number between 0 and 1
    rand = random.random()
    
    print(cum_prob_a, cum_prob_b, rand)
    
    # Determine which character to pick based on the random number
    if rand < cum_prob_a:
        return var_a
    elif rand <= cum_prob_b:
        return var_b
    else:
        raise Exception("Unexpected error: random number outside [0, 1]")

# %%
# test function with sample input values. Run this cell multiple times, you should see both A and B appearing

pick_state('A', 0.3, 'B', 0.7)
# Out:
# 0.3 1.0 0.7990777681458257
# 'B'

# %%
# function to get all sequences (even overlapping) of length n in a given string named 'sequence'

def get_n_letter_sequences(sequence, n):
    
    return [sequence[i:i+n] for i in range(len(sequence) - n + 1)]

# %%
# test function with sample string

get_n_letter_sequences('ABBBBABABA', 3)
# Out:
# ['ABB', 'BBB', 'BBB', 'BBA', 'BAB', 'ABA', 'BAB', 'ABA']

# %% [markdown]
# ## read data into dataframe

# %%
df_LAL = pd.read_csv('LALakers_21-23-1-1.csv')
df_LAL
# Out:
#      Unnamed: 0        date result season
# 0             0  2021-10-19      L  21-22
# 1             1  2021-10-22      L  21-22
# 2             2  2021-10-24      W  21-22
# 3             3  2021-10-26      W  21-22
# 4             4  2021-10-27      L  21-22
# ..          ...         ...    ...    ...
# 159         159  2023-04-02    NaN  22-23
# 160         160  2023-04-04    NaN  22-23
# 161         161  2023-04-05    NaN  22-23
# 162         162  2023-04-07    NaN  22-23
# 163         163  2023-04-09    NaN  22-23
#
# [164 rows x 4 columns]

# %% [markdown]
# ## 1st order Markov Chain

# %% [markdown]
# ### training and test data

# %%
# train only on 2021-22 first half

seq_train = ''.join(df_LAL.loc[df_LAL.season=='21-22'][:40]['result'].values)
seq_train
# Out:
# 'LLWWLWWWLLWWLWLLLWLWLWWLWLWWWLLLLLWLWWWW'

# %%
# get test data - second half of 21-22 season

seq_test = df_LAL.loc[df_LAL.season=='21-22'][40:]['result'].values
seq_test
# Out:
# array(['L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'L',
#        'W', 'L', 'L', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'L', 'W',
#        'L', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'L', 'L',
#        'L', 'W', 'W'], dtype=object)

# %% [markdown]
# ### generate transition matrix of order-1 Markov

# %%
# get all sequences of length 1 in the training data
seq_1_list        = np.array(get_n_letter_sequences(seq_train, 1))
unique_seq_1_list = np.sort(np.unique(seq_1_list))

# get all sequences of length 2 in the training data
seq_1plus1_list        = np.array(get_n_letter_sequences(seq_train, 2))
unique_seq_1plus1_list = np.sort(np.unique(seq_1plus1_list))

# create an empty matrix that will eventually hold the transition probabilities
arr_tr_mat = np.zeros((2, unique_seq_1_list.shape[0]))

print ('seq-o' + str(1), '\tseq-o' + str(1+1), '\tcount', '\tprob_of_seq-o' + str(1+1))

for i, seq_n in enumerate(unique_seq_1_list):
    
    # possible next states appended to seq_n. There are only two possibilities
    seq_1plus1_0 = seq_n + 'L'
    seq_1plus1_1 = seq_n + 'W'
    
    # Count all occurrences of the above sequences in all the n+1 length sequences
    count_seq_1plus1_0 = (seq_1plus1_list == seq_1plus1_0).sum()
    count_seq_1plus1_1 = (seq_1plus1_list == seq_1plus1_1).sum()
    
    # get ratios of occurrences of each n+1 length sequence
    prob_seq_1plus1_0 = count_seq_1plus1_0/(count_seq_1plus1_0+count_seq_1plus1_1)
    prob_seq_1plus1_1 = count_seq_1plus1_1/(count_seq_1plus1_0+count_seq_1plus1_1)
    
    # to see the output
    print (seq_n, '\t', seq_1plus1_0, '\t', count_seq_1plus1_0, '\t', round(prob_seq_1plus1_0, 3))
    print (seq_n, '\t', seq_1plus1_1, '\t', count_seq_1plus1_1, '\t', round(prob_seq_1plus1_1, 3))
    
    arr_tr_mat[0][i] = prob_seq_1plus1_0
    arr_tr_mat[1][i] = prob_seq_1plus1_1
    
    
print ('\nTransition Matrix = ')
print (arr_tr_mat)
# Out:
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]

# %% [markdown]
# ### generate predictions and accuracy score for a single stretch

# %%
# generate predictions and accuracy score

# empty array to hold predictions
predictions = []

# last known seq-n state
seq_start = seq_train[-1:]
print ('starting state sequence:', seq_start)

# make N forward predictions. make it the same length as the test data of known outcomes
N = len(seq_test)

for i in range (0, N):
    
    # define the state vector such that there is a '1' corresponding to the value of the starting sequence
    # the '1' should be placed in the row number corresponding to the column number of the starting sequence in the transition matrix 
    # (or unique_seq_1plus1_list)
    state_start = np.where(unique_seq_1_list == seq_start, 1, 0)
    
    # calculate the probabilities of the next state
    state_next_probs = arr_tr_mat @ state_start
    
    # based on the probabilities, pick a state
    state_next = pick_state('L', state_next_probs[0], 'W', state_next_probs[1])
    # print ('predicted state next:', state_next, 'prob(L)=',round(state_next_probs[0], 2))
    
    # the next sequence will now include the forecasted state
    # add next state to the current start state, then take only the last n-state sequence to be the next start state
    seq_start = (seq_start + state_next)[-1:]
    
    # print ('next starting state sequence:', seq_start)
    predictions.append(state_next)
    
print ('\n>> forecast of ' + str(len(seq_test)) + ' states')
print (predictions)

# make a new dataframe holding the actual known outcomes (seq_test) and the predictions. 
df_validation = pd.DataFrame({'actual': seq_test, 'predicted': np.array(predictions)})

# get accuracy of individual predictions
acc = df_validation.loc[df_validation.actual==df_validation.predicted].shape[0]/df_validation.shape[0]

print ('accuracy rate: ', round(acc, 3))
# Out:
# starting state sequence: W
# 0.5 1.0 0.2961921418311545
# 0.42105263157894735 1.0 0.24340786317069585
# 0.42105263157894735 1.0 0.43165735917034553
# 0.5 1.0 0.06081814029761712
# 0.42105263157894735 1.0 0.8476353616530946
# 0.5 1.0 0.477160832460912
# 0.42105263157894735 1.0 0.7011002694783188
# 0.5 1.0 0.8361973859872915
# 0.5 1.0 0.14521389324815137
# 0.42105263157894735 1.0 0.9879824136184703
# 0.5 1.0 0.9852808341283527
# 0.5 1.0 0.5079393457327014
# 0.5 1.0 0.6315671022841509
# 0.5 1.0 0.06214759835361128
# 0.42105263157894735 1.0 0.7078561223932164
# 0.5 1.0 0.24819403530094586
# 0.42105263157894735 1.0 0.8206154759097367
# 0.5 1.0 0.7659030417438731
# 0.5 1.0 0.7812230428002002
# 0.5 1.0 0.6204311259007351
# 0.5 1.0 0.21348079992282953
# 0.42105263157894735 1.0 0.8601999890590494
# 0.5 1.0 0.2395262802295609
# 0.42105263157894735 1.0 0.3719874209024753
# 0.42105263157894735 1.0 0.7213562866133447
# 0.5 1.0 0.7531878258181838
# 0.5 1.0 0.6411902031418549
# 0.5 1.0 0.9210858335500394
# 0.5 1.0 0.33860215675966254
# 0.42105263157894735 1.0 0.20369616378587163
# 0.42105263157894735 1.0 0.27324863735000826
# 0.42105263157894735 1.0 0.3297610529716787
# 0.42105263157894735 1.0 0.9908902554386103
# 0.5 1.0 0.9579774721272929
# 0.5 1.0 0.08671210283155184
# 0.42105263157894735 1.0 0.2114223425942212
# 0.42105263157894735 1.0 0.7439182677745196
# 0.5 1.0 0.9858825263699553
# 0.5 1.0 0.2860093500338434
# 0.42105263157894735 1.0 0.3160614833212878
# 0.42105263157894735 1.0 0.6509391005109522
# 0.5 1.0 0.028065437804299376
#
# >> forecast of 42 states
# ['L', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'W', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'L']
# accuracy rate:  0.405

# %% [markdown]
# ### Your work below

# %%
# Q4

def get_transition_matrix_order_n(seq_train, order):
    # get all sequences of length n (order) in the training data
    seq_n_list = np.array(get_n_letter_sequences(seq_train, order))
    unique_seq_n_list = np.sort(np.unique(seq_n_list))
    
    # get all sequences of length (n+1) in the training data
    seq_nplus1_list = np.array(get_n_letter_sequences(seq_train, order + 1))
    unique_seq_nplus1_list = np.sort(np.unique(seq_nplus1_list))
    
    # create an empty matrix that will eventually hold the transition probabilities
    arr_tr_mat = np.zeros((2, len(unique_seq_n_list)))
    
    print('seq-o' + str(order), '\tseq-o' + str(order + 1), '\tcount', '\tprob_of_seq-o' + str(order + 1))

    # Loop through each unique sequence of length n
    for i, seq_n in enumerate(unique_seq_n_list):
        # possible next states appended to seq_n. There are only two possibilities
        seq_nplus1_0 = seq_n + 'L'
        seq_nplus1_1 = seq_n + 'W'
        
        # count all occurrences of the above sequences in all the n+1 length sequences
        count_seq_nplus1_0 = (seq_nplus1_list == seq_nplus1_0).sum()
        count_seq_nplus1_1 = (seq_nplus1_list == seq_nplus1_1).sum()
        total_count = count_seq_nplus1_0 + count_seq_nplus1_1
        
        # get ratios of occurrences of each n+1 length sequence
        prob_seq_nplus1_0 = count_seq_nplus1_0 / (count_seq_nplus1_0 + count_seq_nplus1_1) if total_count != 0 else 0
        prob_seq_nplus1_1 = count_seq_nplus1_1 / (count_seq_nplus1_0 + count_seq_nplus1_1) if total_count != 0 else 0
        
        # print the output for each sequence
        print(seq_n, '\t', seq_nplus1_0, '\t', count_seq_nplus1_0, '\t', round(prob_seq_nplus1_0, 3))
        print(seq_n, '\t', seq_nplus1_1, '\t', count_seq_nplus1_1, '\t', round(prob_seq_nplus1_1, 3))
        
        # assign transition probabilities to the transition matrix
        arr_tr_mat[0][i] = prob_seq_nplus1_0
        arr_tr_mat[1][i] = prob_seq_nplus1_1
    
    print('\nTransition Matrix = ')
    print(arr_tr_mat)
    
    return arr_tr_mat

# %%
get_transition_matrix_order_n(seq_train, 1)
# Out:
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# array([[0.42105263, 0.5       ],
#        [0.57894737, 0.5       ]])

# %%
get_transition_matrix_order_n(seq_train, 2)
# Out:
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# array([[0.5       , 0.45454545, 0.3       , 0.55555556],
#        [0.5       , 0.54545455, 0.7       , 0.44444444]])

# %%
get_transition_matrix_order_n(seq_train, 3)
# Out:
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# array([[0.5       , 0.5       , 0.2       , 0.5       , 0.66666667,
#         0.42857143, 0.4       , 0.66666667],
#        [0.5       , 0.5       , 0.8       , 0.5       , 0.33333333,
#         0.57142857, 0.6       , 0.33333333]])

# %%
# Q5

def get_prediction_accuracy(seq_train, seq_test, order):
    
    # call the nested function to get the transition matrix
    arr_tr_mat = get_transition_matrix_order_n(seq_train, order)
    
    # fetch necessary variables from the transition matrix
    seq_n_list = np.array(get_n_letter_sequences(seq_train, order))
    unique_seq_n_list = np.sort(np.unique(seq_n_list))
    
    # empty array to hold predictions
    predictions = []

    # last known seq-n state
    seq_start = seq_train[-order:]

    # make N forward predictions. make it the same length as the test data of known outcomes
    N = len(seq_test)

    for i in range(N):
        # define the state vector such that there is a '1' corresponding to the value of the starting sequence
        # the '1' should be placed in the row number corresponding to the column number of the starting sequence in the transition matrix 
        # (or unique_seq_1plus1_list)
        state_start = np.where(unique_seq_n_list == seq_start, 1, 0)

        # calculate the probabilities of the next state
        state_next_probs = arr_tr_mat @ state_start
        
        # based on the probabilities, pick a state
        state_next = pick_state('L', state_next_probs[0], 'W', state_next_probs[1])
        
#         print ('predicted state next:', state_next, 'prob(L)=',round(state_next_probs[0], 2))

        # the next sequence will now include the forecasted state
        # add next state to the current start state, then take only the last n-state sequence to be the next start state
        seq_start = (seq_start + state_next)[-order:]

        predictions.append(state_next)
        
    print ('\n>> forecast of ' + str(len(seq_test)) + ' states')
    print (predictions)

    # make a new dataframe holding the actual known outcomes (seq_test) and the predictions. 
    df_validation = pd.DataFrame({'actual': seq_test, 'predicted': np.array(predictions)})

    # get accuracy of individual predictions
    acc = df_validation.loc[df_validation.actual == df_validation.predicted].shape[0] / df_validation.shape[0]

    return acc
    print('Accuracy rate:', round(acc, 3))

# %%
get_prediction_accuracy(seq_train, seq_test, 1)
# Out:
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.28999199174259804
# 0.42105263157894735 1.0 0.19213250069206678
# 0.42105263157894735 1.0 0.12758307152005832
# 0.42105263157894735 1.0 0.03328188403462473
# 0.42105263157894735 1.0 0.4052325440393423
# 0.42105263157894735 1.0 0.7977340243635631
# 0.5 1.0 0.6185702814148093
# 0.5 1.0 0.1248339074532806
# 0.42105263157894735 1.0 0.9292206707788695
# 0.5 1.0 0.20844927349843312
# 0.42105263157894735 1.0 0.17169106623759578
# 0.42105263157894735 1.0 0.5489136111146745
# 0.5 1.0 0.13442194219012282
# 0.42105263157894735 1.0 0.14314076826203215
# 0.42105263157894735 1.0 0.06046900768563024
# 0.42105263157894735 1.0 0.0291016705758671
# 0.42105263157894735 1.0 0.1969123632442673
# 0.42105263157894735 1.0 0.9241548396729155
# 0.5 1.0 0.49199460054512245
# 0.42105263157894735 1.0 0.49733260707333626
# 0.5 1.0 0.9313411176311154
# 0.5 1.0 0.49722973919783886
# 0.42105263157894735 1.0 0.7037436634951514
# 0.5 1.0 0.7154649958253875
# 0.5 1.0 0.6024690750193548
# 0.5 1.0 0.709270311706944
# 0.5 1.0 0.4066109751538056
# 0.42105263157894735 1.0 0.5095479501848962
# 0.5 1.0 0.7092960364636617
# 0.5 1.0 0.4765242759317493
# 0.42105263157894735 1.0 0.3946320014528296
# 0.42105263157894735 1.0 0.006906754045239438
# 0.42105263157894735 1.0 0.3272640071499602
# 0.42105263157894735 1.0 0.19745554411094224
# 0.42105263157894735 1.0 0.8548162946938686
# 0.5 1.0 0.8113156737263081
# 0.5 1.0 0.41928182646621925
# 0.42105263157894735 1.0 0.5892925484676151
# 0.5 1.0 0.6630850334638654
# 0.5 1.0 0.2036073455261863
# 0.42105263157894735 1.0 0.21221411215403574
# 0.42105263157894735 1.0 0.46596110478751773
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'W']
# 0.5714285714285714

# %%
get_prediction_accuracy(seq_train, seq_test, 2)
# Out:
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.4923327784804844
# 0.3 1.0 0.2691122698898235
# 0.5 1.0 0.18856161337083654
# 0.5 1.0 0.48048382391172584
# 0.5 1.0 0.7877165027425387
# 0.45454545454545453 1.0 0.7573337529278523
# 0.5555555555555556 1.0 0.5521383428604549
# 0.3 1.0 0.2377614782697074
# 0.5 1.0 0.7174946962052332
# 0.45454545454545453 1.0 0.3875456617840033
# 0.3 1.0 0.698078614245388
# 0.45454545454545453 1.0 0.5024349252735761
# 0.5555555555555556 1.0 0.9988559832732982
# 0.5555555555555556 1.0 0.9590034993336306
# 0.5555555555555556 1.0 0.2055214560840446
# 0.3 1.0 0.3800267301528588
# 0.45454545454545453 1.0 0.7578930654054613
# 0.5555555555555556 1.0 0.4518952151665161
# 0.3 1.0 0.7120827112125181
# 0.45454545454545453 1.0 0.058152197994715604
# 0.3 1.0 0.06387261317667281
# 0.5 1.0 0.07105013054373077
# 0.5 1.0 0.6910835120484868
# 0.45454545454545453 1.0 0.6879489930907845
# 0.5555555555555556 1.0 0.4832454197636338
# 0.3 1.0 0.8160656434580056
# 0.45454545454545453 1.0 0.5050496284720482
# 0.5555555555555556 1.0 0.823465256619518
# 0.5555555555555556 1.0 0.36187778267511905
# 0.3 1.0 0.6063314400136046
# 0.45454545454545453 1.0 0.36202166316800033
# 0.3 1.0 0.9343753683736035
# 0.45454545454545453 1.0 0.35652804759163215
# 0.3 1.0 0.6500877302625212
# 0.45454545454545453 1.0 0.6274488287129913
# 0.5555555555555556 1.0 0.7569216175306372
# 0.5555555555555556 1.0 0.6255172036105422
# 0.5555555555555556 1.0 0.7448036347899889
# 0.5555555555555556 1.0 0.8638896956412473
# 0.5555555555555556 1.0 0.9846833571788896
# 0.5555555555555556 1.0 0.8798471147295048
# 0.5555555555555556 1.0 0.7834347844471634
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W']
# 0.5238095238095238

# %%
get_prediction_accuracy(seq_train, seq_test, 3)
# Out:
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.942246210355752
# 0.6666666666666666 1.0 0.7171855724376861
# 0.6666666666666666 1.0 0.46545459513915055
# 0.4 1.0 0.3276984101405066
# 0.6666666666666666 1.0 0.23316194603940388
# 0.5 1.0 0.6877053717289318
# 0.5 1.0 0.5745156089552124
# 0.5 1.0 0.47146063336644506
# 0.4 1.0 0.6271179221086763
# 0.42857142857142855 1.0 0.23976438001524036
# 0.2 1.0 0.15931943940746796
# 0.6666666666666666 1.0 0.2747351153033486
# 0.5 1.0 0.3482572373609606
# 0.5 1.0 0.8433449356252737
# 0.5 1.0 0.12152775287800066
# 0.2 1.0 0.2569347399402594
# 0.42857142857142855 1.0 0.18321221817348876
# 0.2 1.0 0.5256469701555935
# 0.42857142857142855 1.0 0.13628029007721454
# 0.2 1.0 0.3096333049211133
# 0.42857142857142855 1.0 0.9420998269478602
# 0.5 1.0 0.9439185821379474
# 0.6666666666666666 1.0 0.1781488485034307
# 0.4 1.0 0.5698165603049787
# 0.42857142857142855 1.0 0.25888488857885883
# 0.2 1.0 0.12543078098217675
# 0.6666666666666666 1.0 0.011186565819478633
# 0.5 1.0 0.040872285346974624
# 0.5 1.0 0.5342267639988783
# 0.5 1.0 0.4750059073954548
# 0.2 1.0 0.8850474582634493
# 0.42857142857142855 1.0 0.16479054290056505
# 0.2 1.0 0.7855693571802055
# 0.42857142857142855 1.0 0.3793043450130599
# 0.2 1.0 0.7853173593281887
# 0.42857142857142855 1.0 0.4333318529205228
# 0.5 1.0 0.9336612770994543
# 0.6666666666666666 1.0 0.6776721280060182
# 0.6666666666666666 1.0 0.5689549270320133
# 0.4 1.0 0.9603512121200377
# 0.42857142857142855 1.0 0.9857299839915278
# 0.5 1.0 0.7439733140827977
#
# >> forecast of 42 states
# ['W', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'W']
# 0.42857142857142855

# %%
# Q6

num_simulations = 10

# initialize a list to store the results
results = []

# Loop through each order
for order in range(1, 5):
    # initialize a list to store accuracies for this order
    accuracies_for_order = []
    
    # perform multiple simulations
    for _ in range(num_simulations):
        # get the accuracy for this simulation and order
        accuracy = get_prediction_accuracy(seq_train, seq_test, order)
        
        # append the accuracy to the list of accuracies for this order
        accuracies_for_order.append(accuracy)
    
    # store the order number and accuracies in the results list
    results.append({'order': order, 'accuracies': accuracies_for_order})

# convert the results list to a pandas DataFrame for easier manipulation and visualization
results_df = pd.DataFrame(results)

# I've checked and tried to debug but still have an error of 'Unexpected error: random number outside [0, 1]. I have no idea on the reason.
# Out:
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.585638917142396
# 0.5 1.0 0.8698970244609899
# 0.5 1.0 0.019209164121104072
# 0.42105263157894735 1.0 0.5780577403506603
# 0.5 1.0 0.7422167901768146
# 0.5 1.0 0.22156867323017926
# 0.42105263157894735 1.0 0.308590166596615
# 0.42105263157894735 1.0 0.1593413636646086
# 0.42105263157894735 1.0 0.4789098974928837
# 0.5 1.0 0.7084787684646894
# 0.5 1.0 0.5435730132189606
# 0.5 1.0 0.14364834207187394
# 0.42105263157894735 1.0 0.1081052948043365
# 0.42105263157894735 1.0 0.4771451627554041
# 0.5 1.0 0.9433258807360251
# 0.5 1.0 0.059763267232927575
# 0.42105263157894735 1.0 0.442993703961279
# 0.5 1.0 0.8616143403862037
# 0.5 1.0 0.9532847487555451
# 0.5 1.0 0.43190117808732653
# 0.42105263157894735 1.0 0.9684394822331539
# 0.5 1.0 0.33631531570656914
# 0.42105263157894735 1.0 0.600509233072566
# 0.5 1.0 0.24629168700816484
# 0.42105263157894735 1.0 0.19496339772236937
# 0.42105263157894735 1.0 0.6996405747300521
# 0.5 1.0 0.9068689398503982
# 0.5 1.0 0.7504241966925351
# 0.5 1.0 0.9579993551436671
# 0.5 1.0 0.5468346264457077
# 0.5 1.0 0.5743470389760269
# 0.5 1.0 0.06584500485108802
# 0.42105263157894735 1.0 0.18411519073329963
# 0.42105263157894735 1.0 0.8900890457638894
# 0.5 1.0 0.13323890104665026
# 0.42105263157894735 1.0 0.2613776867236852
# 0.42105263157894735 1.0 0.29135913693660387
# 0.42105263157894735 1.0 0.15283114402155717
# 0.42105263157894735 1.0 0.502266670245737
# 0.5 1.0 0.3407999115840046
# 0.42105263157894735 1.0 0.12204068538097634
# 0.42105263157894735 1.0 0.7005273050265511
#
# >> forecast of 42 states
# ['W', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'L', 'W']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.8961689851832536
# 0.5 1.0 0.4020775302256393
# 0.42105263157894735 1.0 0.1037740534519257
# 0.42105263157894735 1.0 0.5619897972929719
# 0.5 1.0 0.0770651997839471
# 0.42105263157894735 1.0 0.9984748487892261
# 0.5 1.0 0.6900614993154464
# 0.5 1.0 0.863177107821209
# 0.5 1.0 0.9569128982422289
# 0.5 1.0 0.41959148965950177
# 0.42105263157894735 1.0 0.20735312706816178
# 0.42105263157894735 1.0 0.12563538257079232
# 0.42105263157894735 1.0 0.40029291020746627
# 0.42105263157894735 1.0 0.1826798198377878
# 0.42105263157894735 1.0 0.1871398838813806
# 0.42105263157894735 1.0 0.3957519229515395
# 0.42105263157894735 1.0 0.8259927944251868
# 0.5 1.0 0.020969829492622383
# 0.42105263157894735 1.0 0.8550659027677685
# 0.5 1.0 0.5249177481465704
# 0.5 1.0 0.6851435500131302
# 0.5 1.0 0.7562991125009254
# 0.5 1.0 0.7755073035127351
# 0.5 1.0 0.1827870674261739
# 0.42105263157894735 1.0 0.14798835029161905
# 0.42105263157894735 1.0 0.8371250941111035
# 0.5 1.0 0.38081190220888184
# 0.42105263157894735 1.0 0.6084715499220602
# 0.5 1.0 0.7438808501971617
# 0.5 1.0 0.6341096992888726
# 0.5 1.0 0.4088453885566944
# 0.42105263157894735 1.0 0.8372602217358509
# 0.5 1.0 0.5330485054285247
# 0.5 1.0 0.9465511369045229
# 0.5 1.0 0.5694843639348772
# 0.5 1.0 0.772238599210507
# 0.5 1.0 0.8964623512986346
# 0.5 1.0 0.19258475129766972
# 0.42105263157894735 1.0 0.5456885529561477
# 0.5 1.0 0.35872274065617193
# 0.42105263157894735 1.0 0.36642937197573255
# 0.42105263157894735 1.0 0.21294601867424667
#
# >> forecast of 42 states
# ['W', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'L']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.5747575989486535
# 0.5 1.0 0.36640668705734514
# 0.42105263157894735 1.0 0.43781224733851254
# 0.5 1.0 0.7212990720315278
# 0.5 1.0 0.8239714467205691
# 0.5 1.0 0.5179674556538969
# 0.5 1.0 0.6148012036198207
# 0.5 1.0 0.35663576752079607
# 0.42105263157894735 1.0 0.417297099299882
# 0.42105263157894735 1.0 0.6477314068011787
# 0.5 1.0 0.5378584760461047
# 0.5 1.0 0.44099742170756717
# 0.42105263157894735 1.0 0.10516450042389891
# 0.42105263157894735 1.0 0.1473535802259135
# 0.42105263157894735 1.0 0.3682672996833143
# 0.42105263157894735 1.0 0.4447435250406585
# 0.5 1.0 0.8825219085286399
# 0.5 1.0 0.11838730948381071
# 0.42105263157894735 1.0 0.029435129986919772
# 0.42105263157894735 1.0 0.34154936341711484
# 0.42105263157894735 1.0 0.5181267443794284
# 0.5 1.0 0.3605418116651806
# 0.42105263157894735 1.0 0.4597833917233437
# 0.5 1.0 0.65844069401482
# 0.5 1.0 0.23949437866797973
# 0.42105263157894735 1.0 0.38459573667817915
# 0.42105263157894735 1.0 0.25303384775097837
# 0.42105263157894735 1.0 0.453339479997254
# 0.5 1.0 0.23620385264583876
# 0.42105263157894735 1.0 0.48228284186603465
# 0.5 1.0 0.6049657923044195
# 0.5 1.0 0.9339882587150372
# 0.5 1.0 0.16920846055232053
# 0.42105263157894735 1.0 0.8748215053917534
# 0.5 1.0 0.632759754579831
# 0.5 1.0 0.8134887487124286
# 0.5 1.0 0.08064347191686216
# 0.42105263157894735 1.0 0.8925530582858139
# 0.5 1.0 0.38837259272559554
# 0.42105263157894735 1.0 0.536625411545077
# 0.5 1.0 0.8223293102155437
# 0.5 1.0 0.49280279766077517
#
# >> forecast of 42 states
# ['W', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.42402401240730137
# 0.42105263157894735 1.0 0.7453647196338351
# 0.5 1.0 0.9609322767672729
# 0.5 1.0 0.4884028106880789
# 0.42105263157894735 1.0 0.18657059726473246
# 0.42105263157894735 1.0 0.40986333244390016
# 0.42105263157894735 1.0 0.30579468814237076
# 0.42105263157894735 1.0 0.49133588700266195
# 0.5 1.0 0.9439605412800309
# 0.5 1.0 0.6145566364613523
# 0.5 1.0 0.6449590613503132
# 0.5 1.0 0.5757295146042297
# 0.5 1.0 0.1249381086156699
# 0.42105263157894735 1.0 0.3493914552133851
# 0.42105263157894735 1.0 0.32009731025957155
# 0.42105263157894735 1.0 0.4261630151253548
# 0.5 1.0 0.4010743452952139
# 0.42105263157894735 1.0 0.8650458862722898
# 0.5 1.0 0.8555472993894653
# 0.5 1.0 0.2002286759419306
# 0.42105263157894735 1.0 0.46661863341556487
# 0.5 1.0 0.8951312159258782
# 0.5 1.0 0.9491872252769815
# 0.5 1.0 0.7133875196935957
# 0.5 1.0 0.5136339417781686
# 0.5 1.0 0.05182086423333199
# 0.42105263157894735 1.0 0.6740391681244307
# 0.5 1.0 0.24986005177773973
# 0.42105263157894735 1.0 0.44301385977916874
# 0.5 1.0 0.228968649094332
# 0.42105263157894735 1.0 0.7944845399601871
# 0.5 1.0 0.7926869950315477
# 0.5 1.0 0.7781834287061153
# 0.5 1.0 0.1248139913204851
# 0.42105263157894735 1.0 0.8167535281439176
# 0.5 1.0 0.215403530458964
# 0.42105263157894735 1.0 0.6306088742801967
# 0.5 1.0 0.32937243600198396
# 0.42105263157894735 1.0 0.3951264027483973
# 0.42105263157894735 1.0 0.7819252933782875
# 0.5 1.0 0.8349381154682903
# 0.5 1.0 0.753352190589104
#
# >> forecast of 42 states
# ['L', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'W', 'W']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.6038558830389014
# 0.5 1.0 0.39936841088244823
# 0.42105263157894735 1.0 0.21340014226002213
# 0.42105263157894735 1.0 0.5483549103900229
# 0.5 1.0 0.9230552114229721
# 0.5 1.0 0.6120860366776698
# 0.5 1.0 0.6992121495095392
# 0.5 1.0 0.22465099452913706
# 0.42105263157894735 1.0 0.8387262223476866
# 0.5 1.0 0.5506982237470867
# 0.5 1.0 0.24543534863227645
# 0.42105263157894735 1.0 0.512298078391615
# 0.5 1.0 0.6292012167056994
# 0.5 1.0 0.508767392520567
# 0.5 1.0 0.7027860171315027
# 0.5 1.0 0.3839666541486183
# 0.42105263157894735 1.0 0.5165036615877194
# 0.5 1.0 0.586931396623459
# 0.5 1.0 0.9438421618958158
# 0.5 1.0 0.7540284514058714
# 0.5 1.0 0.4072213949632544
# 0.42105263157894735 1.0 0.7053922299329553
# 0.5 1.0 0.9477591207883952
# 0.5 1.0 0.21317357859754726
# 0.42105263157894735 1.0 0.038326421566661106
# 0.42105263157894735 1.0 0.23492231916151596
# 0.42105263157894735 1.0 0.9696075698841161
# 0.5 1.0 0.5588660008550529
# 0.5 1.0 0.6111736213772646
# 0.5 1.0 0.29654071752399025
# 0.42105263157894735 1.0 0.617270898417531
# 0.5 1.0 0.7854838236903706
# 0.5 1.0 0.6770948209788655
# 0.5 1.0 0.7514301524307886
# 0.5 1.0 0.7405809336347541
# 0.5 1.0 0.9882125464119906
# 0.5 1.0 0.9429600904151574
# 0.5 1.0 0.756035087521259
# 0.5 1.0 0.7720059397591922
# 0.5 1.0 0.005098915929317216
# 0.42105263157894735 1.0 0.47221994189770233
# 0.5 1.0 0.8797572260869158
#
# >> forecast of 42 states
# ['W', 'L', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'W']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.2961662956256824
# 0.42105263157894735 1.0 0.058985653381583014
# 0.42105263157894735 1.0 0.25896906814538745
# 0.42105263157894735 1.0 0.053669619152026615
# 0.42105263157894735 1.0 0.019486127009377463
# 0.42105263157894735 1.0 0.06463707556052856
# 0.42105263157894735 1.0 0.1755827756203735
# 0.42105263157894735 1.0 0.45100083570880267
# 0.5 1.0 0.1756218057745782
# 0.42105263157894735 1.0 0.5976204783758365
# 0.5 1.0 0.3780235299247158
# 0.42105263157894735 1.0 0.7870067896203563
# 0.5 1.0 0.0865000678119826
# 0.42105263157894735 1.0 0.23230952328105003
# 0.42105263157894735 1.0 0.3926528971468708
# 0.42105263157894735 1.0 0.2672190185158918
# 0.42105263157894735 1.0 0.40639223048877404
# 0.42105263157894735 1.0 0.9522965831936391
# 0.5 1.0 0.21896626559984778
# 0.42105263157894735 1.0 0.6173769048028802
# 0.5 1.0 0.03912913251530237
# 0.42105263157894735 1.0 0.2402794404309736
# 0.42105263157894735 1.0 0.4198871765911303
# 0.42105263157894735 1.0 0.7096906566201601
# 0.5 1.0 0.09508309612621679
# 0.42105263157894735 1.0 0.6604217929768058
# 0.5 1.0 0.5971539932014474
# 0.5 1.0 0.3170702882296016
# 0.42105263157894735 1.0 0.20613150039674433
# 0.42105263157894735 1.0 0.5430278754793112
# 0.5 1.0 0.04250279880172769
# 0.42105263157894735 1.0 0.25704723454189293
# 0.42105263157894735 1.0 0.893890972365687
# 0.5 1.0 0.012647110730761968
# 0.42105263157894735 1.0 0.34030482472701673
# 0.42105263157894735 1.0 0.9341734474318096
# 0.5 1.0 0.9827663741370447
# 0.5 1.0 0.2381091462975342
# 0.42105263157894735 1.0 0.7696985786746912
# 0.5 1.0 0.3920244416312849
# 0.42105263157894735 1.0 0.06340525845226919
# 0.42105263157894735 1.0 0.16930272969513394
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'L', 'L', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'L', 'L']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.9050119525421841
# 0.5 1.0 0.053608099399595543
# 0.42105263157894735 1.0 0.1328217925459544
# 0.42105263157894735 1.0 0.15340398707712521
# 0.42105263157894735 1.0 0.7561281356193688
# 0.5 1.0 0.5144144109635508
# 0.5 1.0 0.8218975359846346
# 0.5 1.0 0.8836102675601024
# 0.5 1.0 0.6501268977864102
# 0.5 1.0 0.06509631792423565
# 0.42105263157894735 1.0 0.07556281186874325
# 0.42105263157894735 1.0 0.574939564765585
# 0.5 1.0 0.28746628861611867
# 0.42105263157894735 1.0 0.278869040299753
# 0.42105263157894735 1.0 0.3100178406289248
# 0.42105263157894735 1.0 0.40727542027389585
# 0.42105263157894735 1.0 0.44630309041317384
# 0.5 1.0 0.6201436244298306
# 0.5 1.0 0.06641656098734317
# 0.42105263157894735 1.0 0.2516850777763485
# 0.42105263157894735 1.0 0.16861287047248252
# 0.42105263157894735 1.0 0.6093500507947238
# 0.5 1.0 0.9284308779543181
# 0.5 1.0 0.9270220349096658
# 0.5 1.0 0.06821636298603406
# 0.42105263157894735 1.0 0.42619094835227933
# 0.5 1.0 0.9650080705754959
# 0.5 1.0 0.7698709701110045
# 0.5 1.0 0.2376940879141437
# 0.42105263157894735 1.0 0.5388639048089973
# 0.5 1.0 0.43010930558159943
# 0.42105263157894735 1.0 0.6412540744952842
# 0.5 1.0 0.34315249809042203
# 0.42105263157894735 1.0 0.7230713524498265
# 0.5 1.0 0.04674351088229722
# 0.42105263157894735 1.0 0.7719831936730472
# 0.5 1.0 0.8424571146590596
# 0.5 1.0 0.11847255738205231
# 0.42105263157894735 1.0 0.5337807738974735
# 0.5 1.0 0.3800906334507428
# 0.42105263157894735 1.0 0.49581819549223893
# 0.5 1.0 0.9884279789257479
#
# >> forecast of 42 states
# ['W', 'L', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.27935103476124135
# 0.42105263157894735 1.0 0.1119435939728004
# 0.42105263157894735 1.0 0.2984749356252667
# 0.42105263157894735 1.0 0.3947904138746354
# 0.42105263157894735 1.0 0.6995030759739186
# 0.5 1.0 0.5514686198040797
# 0.5 1.0 0.9201149989141942
# 0.5 1.0 0.30802624619774677
# 0.42105263157894735 1.0 0.571445281890247
# 0.5 1.0 0.23276013351256275
# 0.42105263157894735 1.0 0.8540295191191379
# 0.5 1.0 0.8513517190766954
# 0.5 1.0 0.2428876631186011
# 0.42105263157894735 1.0 0.5970364494222589
# 0.5 1.0 0.676418975387806
# 0.5 1.0 0.0782218774719674
# 0.42105263157894735 1.0 0.19366550902659985
# 0.42105263157894735 1.0 0.8532542535116117
# 0.5 1.0 0.39449706170135734
# 0.42105263157894735 1.0 0.8551193293468559
# 0.5 1.0 0.6139466893108558
# 0.5 1.0 0.08857689185326889
# 0.42105263157894735 1.0 0.06415964273055919
# 0.42105263157894735 1.0 0.07991785272975993
# 0.42105263157894735 1.0 0.27877933862648074
# 0.42105263157894735 1.0 0.4198223640058837
# 0.42105263157894735 1.0 0.43012761371351615
# 0.5 1.0 0.7869984055001898
# 0.5 1.0 0.21228445806944618
# 0.42105263157894735 1.0 0.34137015261916226
# 0.42105263157894735 1.0 0.4353111142233066
# 0.5 1.0 0.4773351120417272
# 0.42105263157894735 1.0 0.028058845813350386
# 0.42105263157894735 1.0 0.11861761491641887
# 0.42105263157894735 1.0 0.7037613747982784
# 0.5 1.0 0.4679637149579644
# 0.42105263157894735 1.0 0.4487700788094442
# 0.5 1.0 0.5048178058795196
# 0.5 1.0 0.5752487891529114
# 0.5 1.0 0.19278161735507537
# 0.42105263157894735 1.0 0.8337625773353403
# 0.5 1.0 0.9832431613613324
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.762562395027442
# 0.5 1.0 0.9022491732653704
# 0.5 1.0 0.0839326803082392
# 0.42105263157894735 1.0 0.44673444580513166
# 0.5 1.0 0.3907862813183448
# 0.42105263157894735 1.0 0.1471715201163124
# 0.42105263157894735 1.0 0.4663625866922314
# 0.5 1.0 0.2809153490008147
# 0.42105263157894735 1.0 0.46687877976950476
# 0.5 1.0 0.8527062736413822
# 0.5 1.0 0.8625017952405388
# 0.5 1.0 0.5464033413104876
# 0.5 1.0 0.7812953741485488
# 0.5 1.0 0.8111419742243002
# 0.5 1.0 0.6824909171192612
# 0.5 1.0 0.5375793456631206
# 0.5 1.0 0.1988615112966593
# 0.42105263157894735 1.0 0.07719614870225988
# 0.42105263157894735 1.0 0.7890307355936022
# 0.5 1.0 0.9801666340631502
# 0.5 1.0 0.8986176316261933
# 0.5 1.0 0.800776147879797
# 0.5 1.0 0.7803497602363094
# 0.5 1.0 0.45890437731127787
# 0.42105263157894735 1.0 0.7217861804727377
# 0.5 1.0 0.5770779194396349
# 0.5 1.0 0.10963544186413088
# 0.42105263157894735 1.0 0.5377656229086876
# 0.5 1.0 0.9193542334432027
# 0.5 1.0 0.015865505757835408
# 0.42105263157894735 1.0 0.2567812269337496
# 0.42105263157894735 1.0 0.6022330711871055
# 0.5 1.0 0.7365406015604394
# 0.5 1.0 0.7771613296037192
# 0.5 1.0 0.28266527116879814
# 0.42105263157894735 1.0 0.8074704099380401
# 0.5 1.0 0.04643601186269253
# 0.42105263157894735 1.0 0.27181836010497695
# 0.42105263157894735 1.0 0.16393240298837275
# 0.42105263157894735 1.0 0.17961682914028398
# 0.42105263157894735 1.0 0.32211244611709533
# 0.42105263157894735 1.0 0.4862274710009725
#
# >> forecast of 42 states
# ['W', 'W', 'L', 'W', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'W']
# seq-o1 	seq-o2 	count 	prob_of_seq-o2
# L 	 LL 	 8 	 0.421
# L 	 LW 	 11 	 0.579
# W 	 WL 	 10 	 0.5
# W 	 WW 	 10 	 0.5
#
# Transition Matrix =
# [[0.42105263 0.5       ]
#  [0.57894737 0.5       ]]
# 0.5 1.0 0.9481276831045984
# 0.5 1.0 0.030974588981579676
# 0.42105263157894735 1.0 0.20490054707152927
# 0.42105263157894735 1.0 0.08536642479355094
# 0.42105263157894735 1.0 0.6635268652480242
# 0.5 1.0 0.1589327562548073
# 0.42105263157894735 1.0 0.8692263009042152
# 0.5 1.0 0.9691272646390122
# 0.5 1.0 0.09715975627521845
# 0.42105263157894735 1.0 0.6308366709893598
# 0.5 1.0 0.18490334947011888
# 0.42105263157894735 1.0 0.24319978410123833
# 0.42105263157894735 1.0 0.20273614009843344
# 0.42105263157894735 1.0 0.013524664697118882
# 0.42105263157894735 1.0 0.9897457914469105
# 0.5 1.0 0.9970363392443276
# 0.5 1.0 0.2664391547770252
# 0.42105263157894735 1.0 0.1221627847179515
# 0.42105263157894735 1.0 0.43839858181830016
# 0.5 1.0 0.20528154166802037
# 0.42105263157894735 1.0 0.44956709893577584
# 0.5 1.0 0.8800853389901283
# 0.5 1.0 0.9012165176440797
# 0.5 1.0 0.3217751199071196
# 0.42105263157894735 1.0 0.26859537114236043
# 0.42105263157894735 1.0 0.11188982173675277
# 0.42105263157894735 1.0 0.7288346142012819
# 0.5 1.0 0.8873416764942077
# 0.5 1.0 0.10173942872141961
# 0.42105263157894735 1.0 0.32994625720859183
# 0.42105263157894735 1.0 0.6637700825007579
# 0.5 1.0 0.7678335619058577
# 0.5 1.0 0.9582564827825775
# 0.5 1.0 0.9798438352589683
# 0.5 1.0 0.12976118733349773
# 0.42105263157894735 1.0 0.7957123156260361
# 0.5 1.0 0.24629417765119654
# 0.42105263157894735 1.0 0.6012706509408782
# 0.5 1.0 0.5087320766782328
# 0.5 1.0 0.7447830776488211
# 0.5 1.0 0.45499064738926265
# 0.42105263157894735 1.0 0.5766608471694468
#
# >> forecast of 42 states
# ['W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.6286847606537216
# 0.5555555555555556 1.0 0.29334930350979627
# 0.3 1.0 0.48924235632161706
# 0.45454545454545453 1.0 0.018270159679697473
# 0.3 1.0 0.3491075884098561
# 0.45454545454545453 1.0 0.5782042191745195
# 0.5555555555555556 1.0 0.40565035184007825
# 0.3 1.0 0.7671039992235111
# 0.45454545454545453 1.0 0.28433527908529976
# 0.3 1.0 0.7815781164718038
# 0.45454545454545453 1.0 0.7539765739764098
# 0.5555555555555556 1.0 0.041016090406050476
# 0.3 1.0 0.1840414862678661
# 0.5 1.0 0.46595441982854713
# 0.5 1.0 0.9059848878777786
# 0.45454545454545453 1.0 0.942644089640163
# 0.5555555555555556 1.0 0.8188633775351108
# 0.5555555555555556 1.0 0.9290315890704675
# 0.5555555555555556 1.0 0.9351876500233084
# 0.5555555555555556 1.0 0.24647736398540976
# 0.3 1.0 0.17725658791308785
# 0.5 1.0 0.5978080791881027
# 0.45454545454545453 1.0 0.085366725650866
# 0.3 1.0 0.39898740489832285
# 0.45454545454545453 1.0 0.34701709240040346
# 0.3 1.0 0.6338190085137377
# 0.45454545454545453 1.0 0.604596828199188
# 0.5555555555555556 1.0 0.702228432803557
# 0.5555555555555556 1.0 0.16026601775087967
# 0.3 1.0 0.3482214581351254
# 0.45454545454545453 1.0 0.8448441541428835
# 0.5555555555555556 1.0 0.9043110146818815
# 0.5555555555555556 1.0 0.2587836909847556
# 0.3 1.0 0.6602032868368877
# 0.45454545454545453 1.0 0.8631043901479976
# 0.5555555555555556 1.0 0.4922252911760938
# 0.3 1.0 0.8312914645605658
# 0.45454545454545453 1.0 0.8326938115465428
# 0.5555555555555556 1.0 0.20884495493347766
# 0.3 1.0 0.05887013164355026
# 0.5 1.0 0.975187109965748
# 0.45454545454545453 1.0 0.8767117448019756
#
# >> forecast of 42 states
# ['W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.7588798815037466
# 0.5555555555555556 1.0 0.7223045106501456
# 0.5555555555555556 1.0 0.4007227985199574
# 0.3 1.0 0.05437269155860347
# 0.5 1.0 0.8663598309896328
# 0.45454545454545453 1.0 0.566998807234708
# 0.5555555555555556 1.0 0.6833817378858655
# 0.5555555555555556 1.0 0.6939941469681479
# 0.5555555555555556 1.0 0.7623064058375636
# 0.5555555555555556 1.0 0.9259397911798403
# 0.5555555555555556 1.0 0.9981906799518554
# 0.5555555555555556 1.0 0.6869665782021857
# 0.5555555555555556 1.0 0.359669659683153
# 0.3 1.0 0.26591347254289277
# 0.5 1.0 0.7950058912977848
# 0.45454545454545453 1.0 0.9576959068344212
# 0.5555555555555556 1.0 0.13625850156914787
# 0.3 1.0 0.1975139449276272
# 0.5 1.0 0.6033865818914994
# 0.45454545454545453 1.0 0.6990078574014978
# 0.5555555555555556 1.0 0.6661616375956904
# 0.5555555555555556 1.0 0.4587420932026449
# 0.3 1.0 0.42227208668836114
# 0.45454545454545453 1.0 0.6746463389018198
# 0.5555555555555556 1.0 0.7955975760983893
# 0.5555555555555556 1.0 0.8344094525692043
# 0.5555555555555556 1.0 0.9480978402988255
# 0.5555555555555556 1.0 0.8914108890741422
# 0.5555555555555556 1.0 0.559152602984801
# 0.5555555555555556 1.0 0.48213853024438014
# 0.3 1.0 0.32955635764648883
# 0.45454545454545453 1.0 0.22653401346626023
# 0.3 1.0 0.3614002892785252
# 0.45454545454545453 1.0 0.37315500205066243
# 0.3 1.0 0.8923627017019553
# 0.45454545454545453 1.0 0.9710489914600545
# 0.5555555555555556 1.0 0.2393736066174632
# 0.3 1.0 0.7273293030280988
# 0.45454545454545453 1.0 0.6393139423062233
# 0.5555555555555556 1.0 0.78077690340074
# 0.5555555555555556 1.0 0.3360965440817594
# 0.3 1.0 0.6070592081088593
#
# >> forecast of 42 states
# ['W', 'W', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.48475804095003683
# 0.3 1.0 0.5239198110789983
# 0.45454545454545453 1.0 0.9857440399209796
# 0.5555555555555556 1.0 0.06324636862909927
# 0.3 1.0 0.39280303188940935
# 0.45454545454545453 1.0 0.619836641555892
# 0.5555555555555556 1.0 0.146811420532727
# 0.3 1.0 0.3168064230480453
# 0.45454545454545453 1.0 0.3569085138418746
# 0.3 1.0 0.4742702066876181
# 0.45454545454545453 1.0 0.3255128514553811
# 0.3 1.0 0.22857613934344279
# 0.5 1.0 0.39252355300172237
# 0.5 1.0 0.4231369960724187
# 0.5 1.0 0.8668363411313459
# 0.45454545454545453 1.0 0.7367233312123377
# 0.5555555555555556 1.0 0.7905193579136088
# 0.5555555555555556 1.0 0.4089561758715602
# 0.3 1.0 0.8374229478214962
# 0.45454545454545453 1.0 0.24945815288959639
# 0.3 1.0 0.6792257696265407
# 0.45454545454545453 1.0 0.06270377122280324
# 0.3 1.0 0.629617637005254
# 0.45454545454545453 1.0 0.8233928290884492
# 0.5555555555555556 1.0 0.22198056640870023
# 0.3 1.0 0.046168872893630364
# 0.5 1.0 0.08377715107079153
# 0.5 1.0 0.1395385259925883
# 0.5 1.0 0.5215639018121607
# 0.45454545454545453 1.0 0.75511262927144
# 0.5555555555555556 1.0 0.6668796243734604
# 0.5555555555555556 1.0 0.5870855264825238
# 0.5555555555555556 1.0 0.5173505874659406
# 0.3 1.0 0.3490360098969101
# 0.45454545454545453 1.0 0.3409030769377608
# 0.3 1.0 0.5084575806063515
# 0.45454545454545453 1.0 0.642436475606606
# 0.5555555555555556 1.0 0.14555869464681848
# 0.3 1.0 0.73945522566468
# 0.45454545454545453 1.0 0.6471420027812699
# 0.5555555555555556 1.0 0.08378354115962594
# 0.3 1.0 0.2940517129478112
#
# >> forecast of 42 states
# ['L', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'L']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.5982384990281838
# 0.5555555555555556 1.0 0.45589800366559197
# 0.3 1.0 0.432228235558088
# 0.45454545454545453 1.0 0.8620704697523343
# 0.5555555555555556 1.0 0.5024535146722329
# 0.3 1.0 0.16229277938227238
# 0.5 1.0 0.31638295172592923
# 0.5 1.0 0.9317653001621359
# 0.45454545454545453 1.0 0.25923408564401274
# 0.3 1.0 0.5398475827050089
# 0.45454545454545453 1.0 0.05822729534099724
# 0.3 1.0 0.25776773332916647
# 0.5 1.0 0.1482315766230624
# 0.5 1.0 0.8709140544146639
# 0.45454545454545453 1.0 0.08588668197278437
# 0.3 1.0 0.6194205172914724
# 0.45454545454545453 1.0 0.9868903724244136
# 0.5555555555555556 1.0 0.3951921085042427
# 0.3 1.0 0.4757439266435226
# 0.45454545454545453 1.0 0.37267553636972695
# 0.3 1.0 0.4045641650281274
# 0.45454545454545453 1.0 0.6891168419983571
# 0.5555555555555556 1.0 0.3926649591706497
# 0.3 1.0 0.7788111315384992
# 0.45454545454545453 1.0 0.5376880717385102
# 0.5555555555555556 1.0 0.13060504319611865
# 0.3 1.0 0.8636472119450482
# 0.45454545454545453 1.0 0.09054340446455134
# 0.3 1.0 0.9894173954705595
# 0.45454545454545453 1.0 0.4812799322418858
# 0.5555555555555556 1.0 0.23465645812580693
# 0.3 1.0 0.23709361966281772
# 0.5 1.0 0.5571900748662199
# 0.45454545454545453 1.0 0.5891660670580686
# 0.5555555555555556 1.0 0.401396535064916
# 0.3 1.0 0.6578627769967695
# 0.45454545454545453 1.0 0.07632163735759545
# 0.3 1.0 0.7742920075585988
# 0.45454545454545453 1.0 0.6117955100860627
# 0.5555555555555556 1.0 0.27909111565933586
# 0.3 1.0 0.12489845498352015
# 0.5 1.0 0.5470646670641949
#
# >> forecast of 42 states
# ['W', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.5941430458642187
# 0.5555555555555556 1.0 0.21882967614196847
# 0.3 1.0 0.17659682916091624
# 0.5 1.0 0.561089607579329
# 0.45454545454545453 1.0 0.11404890212234942
# 0.3 1.0 0.7538733985499203
# 0.45454545454545453 1.0 0.44319274467578085
# 0.3 1.0 0.9296982134844923
# 0.45454545454545453 1.0 0.05274846470733463
# 0.3 1.0 0.5180602258741542
# 0.45454545454545453 1.0 0.2406042814452919
# 0.3 1.0 0.5634857072766881
# 0.45454545454545453 1.0 0.057859759557596036
# 0.3 1.0 0.16719424167367314
# 0.5 1.0 0.33822497067163426
# 0.5 1.0 0.8617870589488481
# 0.45454545454545453 1.0 0.7559019147202678
# 0.5555555555555556 1.0 0.02047499913695905
# 0.3 1.0 0.6153007167984114
# 0.45454545454545453 1.0 0.9525513990529012
# 0.5555555555555556 1.0 0.3158835854261335
# 0.3 1.0 0.7927657805307289
# 0.45454545454545453 1.0 0.36460388377892083
# 0.3 1.0 0.6368006237324865
# 0.45454545454545453 1.0 0.1390835925529479
# 0.3 1.0 0.7726413444183816
# 0.45454545454545453 1.0 0.6604775884849683
# 0.5555555555555556 1.0 0.4983137332435311
# 0.3 1.0 0.8050393675073845
# 0.45454545454545453 1.0 0.5106878909177138
# 0.5555555555555556 1.0 0.6063246604607634
# 0.5555555555555556 1.0 0.6901494428730636
# 0.5555555555555556 1.0 0.5051370727086391
# 0.3 1.0 0.48715897130994545
# 0.45454545454545453 1.0 0.16874035101204754
# 0.3 1.0 0.18379087369541702
# 0.5 1.0 0.5975469071397609
# 0.45454545454545453 1.0 0.6846976424628581
# 0.5555555555555556 1.0 0.626197331173382
# 0.5555555555555556 1.0 0.9349102441351128
# 0.5555555555555556 1.0 0.6873904952413528
# 0.5555555555555556 1.0 0.7406979796039108
#
# >> forecast of 42 states
# ['W', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'W', 'W', 'W', 'W', 'W', 'W']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.993977278442911
# 0.5555555555555556 1.0 0.4880204763628939
# 0.3 1.0 0.5837965795658068
# 0.45454545454545453 1.0 0.6147850556968961
# 0.5555555555555556 1.0 0.37802690871544453
# 0.3 1.0 0.8752779967885921
# 0.45454545454545453 1.0 0.36360693861489435
# 0.3 1.0 0.4654745956061066
# 0.45454545454545453 1.0 0.08910073969725918
# 0.3 1.0 0.2511306016290493
# 0.5 1.0 0.9517768143563858
# 0.45454545454545453 1.0 0.5705109438235977
# 0.5555555555555556 1.0 0.026072450482490406
# 0.3 1.0 0.31545685605727425
# 0.45454545454545453 1.0 0.4632803234562497
# 0.5555555555555556 1.0 0.7502598455715886
# 0.5555555555555556 1.0 0.01164046393219309
# 0.3 1.0 0.976939858410648
# 0.45454545454545453 1.0 0.7132565904676285
# 0.5555555555555556 1.0 0.048828416483368
# 0.3 1.0 0.9571770700017415
# 0.45454545454545453 1.0 0.2847599016706669
# 0.3 1.0 0.4090849100823202
# 0.45454545454545453 1.0 0.42057773123068987
# 0.3 1.0 0.6013674976566703
# 0.45454545454545453 1.0 0.3784660653825771
# 0.3 1.0 0.20201552056950722
# 0.5 1.0 0.043591495444731065
# 0.5 1.0 0.5150119153882619
# 0.45454545454545453 1.0 0.40550051429485745
# 0.3 1.0 0.7423596988308457
# 0.45454545454545453 1.0 0.3734846880133459
# 0.3 1.0 0.8250753277155809
# 0.45454545454545453 1.0 0.38145372246042186
# 0.3 1.0 0.057686040798938465
# 0.5 1.0 0.7366784819240426
# 0.45454545454545453 1.0 0.812083773499551
# 0.5555555555555556 1.0 0.22087221324936146
# 0.3 1.0 0.8280679353389387
# 0.45454545454545453 1.0 0.3594274651387881
# 0.3 1.0 0.7151628448221341
# 0.45454545454545453 1.0 0.3879810305763667
#
# >> forecast of 42 states
# ['W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.08950606717535314
# 0.3 1.0 0.5768864595801194
# 0.45454545454545453 1.0 0.2782253966882824
# 0.3 1.0 0.6589522439946547
# 0.45454545454545453 1.0 0.8618066203292045
# 0.5555555555555556 1.0 0.9213538377102239
# 0.5555555555555556 1.0 0.9929105423115379
# 0.5555555555555556 1.0 0.9091237853073059
# 0.5555555555555556 1.0 0.038048248154976094
# 0.3 1.0 0.9615997227606323
# 0.45454545454545453 1.0 0.4372388899953693
# 0.3 1.0 0.696986557383639
# 0.45454545454545453 1.0 0.979427139124451
# 0.5555555555555556 1.0 0.81941015164601
# 0.5555555555555556 1.0 0.12384677041928427
# 0.3 1.0 0.34359390143773416
# 0.45454545454545453 1.0 0.18588018408176277
# 0.3 1.0 0.48066303952729295
# 0.45454545454545453 1.0 0.2543819613930268
# 0.3 1.0 0.7795084707598062
# 0.45454545454545453 1.0 0.36037297550290204
# 0.3 1.0 0.9595291126750172
# 0.45454545454545453 1.0 0.5567400217365893
# 0.5555555555555556 1.0 0.3304748046162088
# 0.3 1.0 0.22838388519071706
# 0.5 1.0 0.9049637813512571
# 0.45454545454545453 1.0 0.8942596884862438
# 0.5555555555555556 1.0 0.4259564161637107
# 0.3 1.0 0.37762782694627717
# 0.45454545454545453 1.0 0.4845298505586444
# 0.5555555555555556 1.0 0.25793456739618426
# 0.3 1.0 0.48160858549351737
# 0.45454545454545453 1.0 0.21965664184947742
# 0.3 1.0 0.4315760013314768
# 0.45454545454545453 1.0 0.4503134064927904
# 0.3 1.0 0.9668817176977894
# 0.45454545454545453 1.0 0.11525244381933142
# 0.3 1.0 0.4890844899067983
# 0.45454545454545453 1.0 0.1925284660259574
# 0.3 1.0 0.3175309786159406
# 0.45454545454545453 1.0 0.8471663761840034
# 0.5555555555555556 1.0 0.6788542810943321
#
# >> forecast of 42 states
# ['L', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.46433560827649256
# 0.3 1.0 0.2164016102534525
# 0.5 1.0 0.31177658190203794
# 0.5 1.0 0.9894730100956027
# 0.45454545454545453 1.0 0.2885535025120173
# 0.3 1.0 0.3953332085593625
# 0.45454545454545453 1.0 0.6931825018922191
# 0.5555555555555556 1.0 0.19477614806490817
# 0.3 1.0 0.9086081128698815
# 0.45454545454545453 1.0 0.6329512023752616
# 0.5555555555555556 1.0 0.4207000197444798
# 0.3 1.0 0.46236530052657454
# 0.45454545454545453 1.0 0.01858220041093872
# 0.3 1.0 0.4522223073755163
# 0.45454545454545453 1.0 0.30806405700559636
# 0.3 1.0 0.026686129006224024
# 0.5 1.0 0.21586101255457635
# 0.5 1.0 0.21275620572914522
# 0.5 1.0 0.45805434316879357
# 0.5 1.0 0.15090861434415648
# 0.5 1.0 0.989610105560755
# 0.45454545454545453 1.0 0.3295001129392292
# 0.3 1.0 0.7793306793695818
# 0.45454545454545453 1.0 0.8378457781429328
# 0.5555555555555556 1.0 0.7815193457574641
# 0.5555555555555556 1.0 0.9923308795254664
# 0.5555555555555556 1.0 0.989478659986432
# 0.5555555555555556 1.0 0.8952305219551013
# 0.5555555555555556 1.0 0.08926405064483822
# 0.3 1.0 0.4073209166874726
# 0.45454545454545453 1.0 0.6483775696004418
# 0.5555555555555556 1.0 0.05370468043127419
# 0.3 1.0 0.7856401671228189
# 0.45454545454545453 1.0 0.3873074915233323
# 0.3 1.0 0.4864136663770128
# 0.45454545454545453 1.0 0.6118275762373144
# 0.5555555555555556 1.0 0.8541808846624517
# 0.5555555555555556 1.0 0.5664558674578285
# 0.5555555555555556 1.0 0.6410371119475865
# 0.5555555555555556 1.0 0.7566160260357487
# 0.5555555555555556 1.0 0.7592084265740804
# 0.5555555555555556 1.0 0.32676809723210376
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'W', 'L']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.8905110054034715
# 0.5555555555555556 1.0 0.858754865206995
# 0.5555555555555556 1.0 0.14104770992042526
# 0.3 1.0 0.04399290796644051
# 0.5 1.0 0.25200258049801905
# 0.5 1.0 0.39957492175504405
# 0.5 1.0 0.7406698145020219
# 0.45454545454545453 1.0 0.2748962934928212
# 0.3 1.0 0.5154430458562905
# 0.45454545454545453 1.0 0.3977167440593118
# 0.3 1.0 0.8470442275379055
# 0.45454545454545453 1.0 0.2634626346601071
# 0.3 1.0 0.3173256723854978
# 0.45454545454545453 1.0 0.5811002935524519
# 0.5555555555555556 1.0 0.5611461407957397
# 0.5555555555555556 1.0 0.5010385751188577
# 0.3 1.0 0.5768048499427533
# 0.45454545454545453 1.0 0.5543184893115132
# 0.5555555555555556 1.0 0.7167626626528363
# 0.5555555555555556 1.0 0.025427927310184728
# 0.3 1.0 0.8948368431239283
# 0.45454545454545453 1.0 0.5066237821164107
# 0.5555555555555556 1.0 0.7976422350248873
# 0.5555555555555556 1.0 0.3066620039437945
# 0.3 1.0 0.05527786043553873
# 0.5 1.0 0.010085588304452386
# 0.5 1.0 0.19213068608694617
# 0.5 1.0 0.17389817502510196
# 0.5 1.0 0.2788762821335876
# 0.5 1.0 0.1024088187626162
# 0.5 1.0 0.659005390945421
# 0.45454545454545453 1.0 0.5880790818292394
# 0.5555555555555556 1.0 0.2961951406848363
# 0.3 1.0 0.20980514463618438
# 0.5 1.0 0.47984232594037324
# 0.5 1.0 0.17681961420260106
# 0.5 1.0 0.774414409275461
# 0.45454545454545453 1.0 0.2736596907719804
# 0.3 1.0 0.661565054806404
# 0.45454545454545453 1.0 0.9383699597296306
# 0.5555555555555556 1.0 0.9218483932220796
# 0.5555555555555556 1.0 0.0506999748628747
#
# >> forecast of 42 states
# ['W', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'L']
# seq-o2 	seq-o3 	count 	prob_of_seq-o3
# LL 	 LLL 	 4 	 0.5
# LL 	 LLW 	 4 	 0.5
# LW 	 LWL 	 5 	 0.455
# LW 	 LWW 	 6 	 0.545
# WL 	 WLL 	 3 	 0.3
# WL 	 WLW 	 7 	 0.7
# WW 	 WWL 	 5 	 0.556
# WW 	 WWW 	 4 	 0.444
#
# Transition Matrix =
# [[0.5        0.45454545 0.3        0.55555556]
#  [0.5        0.54545455 0.7        0.44444444]]
# 0.5555555555555556 1.0 0.20845277964806685
# 0.3 1.0 0.38197323534063066
# 0.45454545454545453 1.0 0.6190191979287417
# 0.5555555555555556 1.0 0.5305110094476848
# 0.3 1.0 0.00586412030235739
# 0.5 1.0 0.4972099175153566
# 0.5 1.0 0.3493848438736412
# 0.5 1.0 0.06855882728589835
# 0.5 1.0 0.45850085574072297
# 0.5 1.0 0.8321259848944089
# 0.45454545454545453 1.0 0.2109007536527775
# 0.3 1.0 0.3197020370607526
# 0.45454545454545453 1.0 0.8241468047551327
# 0.5555555555555556 1.0 0.3821592918107023
# 0.3 1.0 0.13056847571093244
# 0.5 1.0 0.689779753404938
# 0.45454545454545453 1.0 0.9193390949396143
# 0.5555555555555556 1.0 0.1427884388043632
# 0.3 1.0 0.6576728003412549
# 0.45454545454545453 1.0 0.40738886880067615
# 0.3 1.0 0.7543016354001164
# 0.45454545454545453 1.0 0.5758722479848974
# 0.5555555555555556 1.0 0.11743115358790401
# 0.3 1.0 0.9937321831527125
# 0.45454545454545453 1.0 0.6158552535938453
# 0.5555555555555556 1.0 0.8504078508292631
# 0.5555555555555556 1.0 0.6724317478490318
# 0.5555555555555556 1.0 0.10453069027957773
# 0.3 1.0 0.20506260418949207
# 0.5 1.0 0.4770281214119624
# 0.5 1.0 0.5238057886316287
# 0.45454545454545453 1.0 0.22577101638893804
# 0.3 1.0 0.461660749225815
# 0.45454545454545453 1.0 0.626289432846788
# 0.5555555555555556 1.0 0.015680898140215893
# 0.3 1.0 0.920912734541185
# 0.45454545454545453 1.0 0.9428298843293975
# 0.5555555555555556 1.0 0.9618023498731336
# 0.5555555555555556 1.0 0.6156636036434164
# 0.5555555555555556 1.0 0.8752259081231998
# 0.5555555555555556 1.0 0.4474555018211831
# 0.3 1.0 0.21689611861593727
#
# >> forecast of 42 states
# ['L', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.4352124022596455
# 0.4 1.0 0.5634174705186701
# 0.42857142857142855 1.0 0.20333106732016137
# 0.2 1.0 0.55882712006264
# 0.42857142857142855 1.0 0.15826529124720246
# 0.2 1.0 0.08841106899378604
# 0.6666666666666666 1.0 0.6366120028412638
# 0.5 1.0 0.4467835059435652
# 0.5 1.0 0.2671189203042519
# 0.5 1.0 0.568648146115275
# 0.5 1.0 0.9877806960418196
# 0.5 1.0 0.9250076740621809
# 0.6666666666666666 1.0 0.04745075324411152
# 0.4 1.0 0.8370269141548337
# 0.42857142857142855 1.0 0.08376864677035112
# 0.2 1.0 0.895343589710368
# 0.42857142857142855 1.0 0.9820097702971802
# 0.5 1.0 0.8306580953752603
# 0.6666666666666666 1.0 0.6456312615499289
# 0.4 1.0 0.3107890040723462
# 0.6666666666666666 1.0 0.8068453084372998
# 0.5 1.0 0.9495309626360607
# 0.5 1.0 0.4732427437469514
# 0.4 1.0 0.7225258322660069
# 0.42857142857142855 1.0 0.6545186761948419
# 0.5 1.0 0.8894374058025447
# 0.6666666666666666 1.0 0.9440855759525832
# 0.6666666666666666 1.0 0.7290031558318009
# 0.6666666666666666 1.0 0.7202945504372261
# 0.6666666666666666 1.0 0.5633996562146628
# 0.4 1.0 0.7127855423105545
# 0.42857142857142855 1.0 0.6758513595782271
# 0.5 1.0 0.7721539357464692
# 0.6666666666666666 1.0 0.8512992605252718
# 0.6666666666666666 1.0 0.44613657698265574
# 0.4 1.0 0.9862407473147716
# 0.42857142857142855 1.0 0.7512396148092361
# 0.5 1.0 0.9007168915757892
# 0.6666666666666666 1.0 0.8366348091609374
# 0.6666666666666666 1.0 0.7090837667647655
# 0.6666666666666666 1.0 0.655584729262978
# 0.4 1.0 0.34946279092817467
#
# >> forecast of 42 states
# ['L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'W', 'W', 'L', 'L']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.20053802664605924
# 0.4 1.0 0.16687648450538795
# 0.6666666666666666 1.0 0.45250083636684546
# 0.5 1.0 0.03021443578782812
# 0.5 1.0 0.27255213780381105
# 0.5 1.0 0.8745321153167611
# 0.5 1.0 0.7902973753583854
# 0.5 1.0 0.07705314341494207
# 0.4 1.0 0.5577293182145278
# 0.42857142857142855 1.0 0.050193002056419966
# 0.2 1.0 0.9285284136268607
# 0.42857142857142855 1.0 0.1750472494930202
# 0.2 1.0 0.5715668635280624
# 0.42857142857142855 1.0 0.5250405405095332
# 0.5 1.0 0.6361315854812796
# 0.6666666666666666 1.0 0.21834377025940788
# 0.4 1.0 0.8307191277402868
# 0.42857142857142855 1.0 0.2521817629461379
# 0.2 1.0 0.08668544011559953
# 0.6666666666666666 1.0 0.12199719021830657
# 0.5 1.0 0.9610220060726583
# 0.5 1.0 0.8483753739502573
# 0.5 1.0 0.3848356205457095
# 0.4 1.0 0.23531976783106212
# 0.6666666666666666 1.0 0.43704839449425703
# 0.5 1.0 0.9616289815733621
# 0.5 1.0 0.8806559232842092
# 0.5 1.0 0.48789893903304415
# 0.4 1.0 0.6455363056587988
# 0.42857142857142855 1.0 0.2085131758889076
# 0.2 1.0 0.849419163370949
# 0.42857142857142855 1.0 0.3213056515299051
# 0.2 1.0 0.8733638969170696
# 0.42857142857142855 1.0 0.9235094094189662
# 0.5 1.0 0.5946109252392814
# 0.6666666666666666 1.0 0.5009457581610918
# 0.4 1.0 0.4734595910757482
# 0.42857142857142855 1.0 0.7586469956338754
# 0.5 1.0 0.0653380537567515
# 0.4 1.0 0.36074188848496314
# 0.6666666666666666 1.0 0.49084014287686606
# 0.5 1.0 0.16263428079883147
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'L']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.06462781536430362
# 0.4 1.0 0.9669227408132613
# 0.42857142857142855 1.0 0.8209430478939562
# 0.5 1.0 0.9739247179868002
# 0.6666666666666666 1.0 0.41312252524738624
# 0.4 1.0 0.0474060665224465
# 0.6666666666666666 1.0 0.661336639814099
# 0.5 1.0 0.9007400432151582
# 0.5 1.0 0.16647524199531116
# 0.2 1.0 0.7863624823161326
# 0.42857142857142855 1.0 0.5268654612877305
# 0.5 1.0 0.6181063664723242
# 0.6666666666666666 1.0 0.8659826704160833
# 0.6666666666666666 1.0 0.32519911433294124
# 0.4 1.0 0.44439465551335733
# 0.42857142857142855 1.0 0.3771702922602007
# 0.2 1.0 0.13906491815413202
# 0.6666666666666666 1.0 0.644475796705542
# 0.5 1.0 0.06522791807061534
# 0.5 1.0 0.36099512932973954
# 0.5 1.0 0.5391228148911317
# 0.5 1.0 0.7009550376367044
# 0.5 1.0 0.701949347604676
# 0.6666666666666666 1.0 0.25503459290695096
# 0.4 1.0 0.9314431426953446
# 0.42857142857142855 1.0 0.9154383758147749
# 0.5 1.0 0.08750668629736169
# 0.4 1.0 0.5454351551310557
# 0.42857142857142855 1.0 0.9531476587988795
# 0.5 1.0 0.318727685426182
# 0.4 1.0 0.19115419492553554
# 0.6666666666666666 1.0 0.2966458702067174
# 0.5 1.0 0.19630367155498274
# 0.5 1.0 0.5437332770889661
# 0.5 1.0 0.7951840937431535
# 0.5 1.0 0.5821975779048055
# 0.6666666666666666 1.0 0.8468652986122411
# 0.6666666666666666 1.0 0.1069270639782508
# 0.4 1.0 0.209539153975696
# 0.6666666666666666 1.0 0.5106981758469217
# 0.5 1.0 0.01676064764702545
# 0.5 1.0 0.8435259058050038
#
# >> forecast of 42 states
# ['L', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'W']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.24219605217082474
# 0.4 1.0 0.9091098645028842
# 0.42857142857142855 1.0 0.28349483150088406
# 0.2 1.0 0.3193166919526449
# 0.42857142857142855 1.0 0.1569213114489003
# 0.2 1.0 0.2828458308788744
# 0.42857142857142855 1.0 0.3203437440327297
# 0.2 1.0 0.6051718714394909
# 0.42857142857142855 1.0 0.05739113666372653
# 0.2 1.0 0.13576738180140258
# 0.6666666666666666 1.0 0.7824248497074135
# 0.5 1.0 0.952513171638816
# 0.5 1.0 0.0464475311327206
# 0.4 1.0 0.44506570225630004
# 0.42857142857142855 1.0 0.4460764149569191
# 0.5 1.0 0.463777098953152
# 0.4 1.0 0.7370394555223422
# 0.42857142857142855 1.0 0.21485628084186081
# 0.2 1.0 0.8384518060305224
# 0.42857142857142855 1.0 0.3967742214388156
# 0.2 1.0 0.258298076470152
# 0.42857142857142855 1.0 0.24232554342874602
# 0.2 1.0 0.21311120067120648
# 0.42857142857142855 1.0 0.518109312682779
# 0.5 1.0 0.35116067746381874
# 0.4 1.0 0.5690877891163258
# 0.42857142857142855 1.0 0.1556057620900554
# 0.2 1.0 0.8135311842550847
# 0.42857142857142855 1.0 0.29416442458118364
# 0.2 1.0 0.8019827172721842
# 0.42857142857142855 1.0 0.5137293569754009
# 0.5 1.0 0.8064165275614749
# 0.6666666666666666 1.0 0.5174068282366089
# 0.4 1.0 0.41547269169393275
# 0.42857142857142855 1.0 0.010450441537080524
# 0.2 1.0 0.7579741798777078
# ...
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.3770454389669451
# 0.4 1.0 0.03364864648068078
# 0.6666666666666666 1.0 0.8130736114128866
# 0.5 1.0 0.12455108124466863
# 0.2 1.0 0.3077465551392393
# 0.42857142857142855 1.0 0.8953929783623883
# 0.5 1.0 0.8200533579024551
# 0.6666666666666666 1.0 0.17886826162068803
# 0.4 1.0 0.243518539753257
# 0.6666666666666666 1.0 0.09296358962285167
# 0.5 1.0 0.3087971981942912
# 0.5 1.0 0.7955654903984238
# 0.5 1.0 0.4914491014218968
# 0.2 1.0 0.833853865676046
# 0.42857142857142855 1.0 0.8631643596557204
# 0.5 1.0 0.612507038823245
# 0.6666666666666666 1.0 0.11571961329170988
# 0.4 1.0 0.6650841304937669
# 0.42857142857142855 1.0 0.9581512805055202
# 0.5 1.0 0.38760023609659966
# 0.4 1.0 0.16604251729782638
# 0.6666666666666666 1.0 0.7731635804646253
# 0.5 1.0 0.8256197698983744
# 0.5 1.0 0.39486197575403137
# 0.4 1.0 0.8049830394690783
# 0.42857142857142855 1.0 0.2065323984642523
# 0.2 1.0 0.004822496634081852
# 0.6666666666666666 1.0 0.8337345211666103
# 0.5 1.0 0.22469729259002114
# 0.2 1.0 0.7836055663271594
# 0.42857142857142855 1.0 0.1740691477607449
# 0.2 1.0 0.8036462057414211
# 0.42857142857142855 1.0 0.48386916219411
# 0.5 1.0 0.6637503731933853
# 0.6666666666666666 1.0 0.25698243365628715
# 0.4 1.0 0.6213324237429058
# 0.42857142857142855 1.0 0.5318562599874666
# 0.5 1.0 0.8287976352209074
# 0.6666666666666666 1.0 0.5905581208151603
# 0.4 1.0 0.7155917045609289
# 0.42857142857142855 1.0 0.8693497987054887
# 0.5 1.0 0.8188557375670836
#
# >> forecast of 42 states
# ['L', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'W', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.6653167808556814
# 0.4 1.0 0.3841366190937142
# 0.6666666666666666 1.0 0.17697394358035912
# 0.5 1.0 0.4672140348065238
# 0.5 1.0 0.6396581339447585
# 0.5 1.0 0.9590781042769048
# 0.5 1.0 0.7638548551148093
# 0.6666666666666666 1.0 0.3939749857819417
# 0.4 1.0 0.5560342330496512
# 0.42857142857142855 1.0 0.007963722291580266
# 0.2 1.0 0.8494856301004328
# 0.42857142857142855 1.0 0.4202000907594783
# 0.2 1.0 0.47880600770457504
# 0.42857142857142855 1.0 0.37536981651477574
# 0.2 1.0 0.49156638898744287
# 0.42857142857142855 1.0 0.3064812012153624
# 0.2 1.0 0.0808411443371827
# 0.6666666666666666 1.0 0.8091835479608035
# 0.5 1.0 0.21643736167014338
# 0.2 1.0 0.06412863031038452
# 0.6666666666666666 1.0 0.8374178068656081
# 0.5 1.0 0.9818332127219872
# 0.5 1.0 0.6721450715299485
# 0.6666666666666666 1.0 0.5047600011502491
# 0.4 1.0 0.011055725189420773
# 0.6666666666666666 1.0 0.28491389118810906
# 0.5 1.0 0.5817745854665978
# 0.5 1.0 0.7182919110248221
# 0.5 1.0 0.29373152286470394
# 0.4 1.0 0.7693366416221028
# 0.42857142857142855 1.0 0.9419393212497109
# 0.5 1.0 0.9949614374925448
# 0.6666666666666666 1.0 0.3121432085041077
# 0.4 1.0 0.8414589063313548
# 0.42857142857142855 1.0 0.7591225223132743
# 0.5 1.0 0.8897992463501745
# 0.6666666666666666 1.0 0.5073868517572898
# 0.4 1.0 0.6039203981464628
# 0.42857142857142855 1.0 0.1336556248476679
# 0.2 1.0 0.4118133398836371
# 0.42857142857142855 1.0 0.13871760054578153
# 0.2 1.0 0.39481319210856236
#
# >> forecast of 42 states
# ['L', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'L', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.8233685790819028
# 0.6666666666666666 1.0 0.678515713580252
# 0.6666666666666666 1.0 0.8392396037321143
# 0.6666666666666666 1.0 0.28030123674504726
# 0.4 1.0 0.18736455834022914
# 0.6666666666666666 1.0 0.4436216115766535
# 0.5 1.0 0.7193630619177778
# 0.5 1.0 0.36414564555126405
# 0.2 1.0 0.7033048506760106
# 0.42857142857142855 1.0 0.37747042366229255
# 0.2 1.0 0.0652982049570745
# 0.6666666666666666 1.0 0.6188133371426368
# 0.5 1.0 0.266659322728504
# 0.5 1.0 0.9475441813855576
# 0.5 1.0 0.3644589347145064
# 0.2 1.0 0.5394393398939937
# 0.42857142857142855 1.0 0.4186260364536536
# 0.2 1.0 0.347769333019475
# 0.42857142857142855 1.0 0.04478146826189999
# 0.2 1.0 0.12710164861442097
# 0.6666666666666666 1.0 0.8404344659225379
# 0.5 1.0 0.21144962734392914
# 0.2 1.0 0.23142616170085717
# 0.42857142857142855 1.0 0.04080799791860912
# 0.2 1.0 0.024140692067772807
# 0.6666666666666666 1.0 0.4924064371894752
# 0.5 1.0 0.9266452006205161
# 0.5 1.0 0.7615345622382274
# 0.5 1.0 0.9039519551655849
# 0.6666666666666666 1.0 0.24052763144280342
# 0.4 1.0 0.41966518237669304
# 0.42857142857142855 1.0 0.1767310850439745
# 0.2 1.0 0.7450437551315983
# 0.42857142857142855 1.0 0.3883855456237445
# 0.2 1.0 0.6767245254386455
# 0.42857142857142855 1.0 0.6082520132692399
# 0.5 1.0 0.2889684408891703
# 0.4 1.0 0.04402681499724059
# 0.6666666666666666 1.0 0.5493393191363786
# 0.5 1.0 0.0022797738477793317
# 0.5 1.0 0.16393787028684115
# 0.5 1.0 0.09234518220497467
#
# >> forecast of 42 states
# ['W', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'L']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.6359535591759197
# 0.4 1.0 0.8807888707693736
# 0.42857142857142855 1.0 0.023445208319858524
# 0.2 1.0 0.5525316923711316
# 0.42857142857142855 1.0 0.27955605258329275
# 0.2 1.0 0.5072835002006558
# 0.42857142857142855 1.0 0.33544450972378514
# 0.2 1.0 0.6367909925238701
# 0.42857142857142855 1.0 0.7041393896913479
# 0.5 1.0 0.2972305974488926
# 0.4 1.0 0.286946978095064
# 0.6666666666666666 1.0 0.9812365033237794
# 0.5 1.0 0.6416036484704158
# 0.5 1.0 0.5717921632734736
# 0.6666666666666666 1.0 0.20803467202121084
# 0.4 1.0 0.5585049113223546
# 0.42857142857142855 1.0 0.6982262715325923
# 0.5 1.0 0.802828790615593
# 0.6666666666666666 1.0 0.24020335312637564
# 0.4 1.0 0.613210319320494
# 0.42857142857142855 1.0 0.15068653110267294
# 0.2 1.0 0.9641577196008021
# 0.42857142857142855 1.0 0.42692193821193325
# 0.2 1.0 0.17024624877972527
# 0.6666666666666666 1.0 0.856044215206295
# 0.5 1.0 0.47110011912708294
# 0.2 1.0 0.8609092963149155
# 0.42857142857142855 1.0 0.4184357724132697
# 0.2 1.0 0.6314845159982739
# 0.42857142857142855 1.0 0.2758685801478665
# 0.2 1.0 0.7462658924801401
# 0.42857142857142855 1.0 0.41314550045063747
# 0.2 1.0 0.4728994411397446
# 0.42857142857142855 1.0 0.7518739252101437
# 0.5 1.0 0.7180729324354096
# 0.6666666666666666 1.0 0.2553615291010224
# 0.4 1.0 0.527430285651098
# 0.42857142857142855 1.0 0.5317167046360552
# 0.5 1.0 0.17923156317248834
# 0.4 1.0 0.4727816041153612
# 0.42857142857142855 1.0 0.3319241072780402
# 0.2 1.0 0.8184318932431258
#
# >> forecast of 42 states
# ['L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'W', 'W', 'L', 'W', 'L', 'W']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.4987200785525012
# 0.4 1.0 0.8750784717655153
# 0.42857142857142855 1.0 0.1291666088576171
# 0.2 1.0 0.8789149620300934
# 0.42857142857142855 1.0 0.7167665053021266
# 0.5 1.0 0.07506233727043976
# 0.4 1.0 0.31703099339956586
# 0.6666666666666666 1.0 0.2760518127036161
# 0.5 1.0 0.6024032925095821
# 0.5 1.0 0.717233643229296
# 0.5 1.0 0.8235043572955898
# 0.6666666666666666 1.0 0.15722002719785555
# 0.4 1.0 0.0645698781954106
# 0.6666666666666666 1.0 0.17306416805814417
# 0.5 1.0 0.21150773754794883
# 0.5 1.0 0.7504070806468842
# 0.5 1.0 0.2678512985563819
# 0.2 1.0 0.813789803406536
# 0.42857142857142855 1.0 0.0266998874642268
# 0.2 1.0 0.7501310014630528
# 0.42857142857142855 1.0 0.8502414163544537
# 0.5 1.0 0.35331646525613924
# 0.4 1.0 0.08984381513666784
# 0.6666666666666666 1.0 0.9567936468076734
# 0.5 1.0 0.8582469316337552
# 0.5 1.0 0.3532736508392651
# 0.4 1.0 0.0613224664888018
# 0.6666666666666666 1.0 0.39759740020136236
# 0.5 1.0 0.261236318100306
# 0.5 1.0 0.057167715879538505
# 0.5 1.0 0.1088375287220027
# 0.5 1.0 0.7161522234520293
# 0.5 1.0 0.6493243165504019
# 0.5 1.0 0.7350322039685954
# 0.6666666666666666 1.0 0.51615795639705
# 0.4 1.0 0.39895313570312374
# 0.6666666666666666 1.0 0.2634007911482208
# 0.5 1.0 0.7953828633586792
# 0.5 1.0 0.8496340859662322
# 0.5 1.0 0.19629125132415193
# 0.4 1.0 0.7824999349945773
# 0.42857142857142855 1.0 0.43258277278173785
#
# >> forecast of 42 states
# ['L', 'W', 'L', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'L', 'L', 'W', 'W', 'L', 'L', 'L', 'L', 'L', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'W', 'L', 'W', 'W']
# seq-o3 	seq-o4 	count 	prob_of_seq-o4
# LLL 	 LLLL 	 2 	 0.5
# LLL 	 LLLW 	 2 	 0.5
# LLW 	 LLWL 	 2 	 0.5
# LLW 	 LLWW 	 2 	 0.5
# LWL 	 LWLL 	 1 	 0.2
# LWL 	 LWLW 	 4 	 0.8
# LWW 	 LWWL 	 3 	 0.5
# LWW 	 LWWW 	 3 	 0.5
# WLL 	 WLLL 	 2 	 0.667
# WLL 	 WLLW 	 1 	 0.333
# WLW 	 WLWL 	 3 	 0.429
# WLW 	 WLWW 	 4 	 0.571
# WWL 	 WWLL 	 2 	 0.4
# WWL 	 WWLW 	 3 	 0.6
# WWW 	 WWWL 	 2 	 0.667
# WWW 	 WWWW 	 1 	 0.333
#
# Transition Matrix =
# [[0.5        0.5        0.2        0.5        0.66666667 0.42857143
#   0.4        0.66666667]
#  [0.5        0.5        0.8        0.5        0.33333333 0.57142857
#   0.6        0.33333333]]
# 0.6666666666666666 1.0 0.5042126944731499
# 0.4 1.0 0.9356132048465476
# 0.42857142857142855 1.0 0.11376600416305649
# 0.2 1.0 0.0089799191526444
# 0.6666666666666666 1.0 0.25613653413923443
# 0.5 1.0 0.423160922387839
# 0.5 1.0 0.28866813329293406
# 0.5 1.0 0.8801448870682034
# 0.5 1.0 0.22540496002098642
# 0.2 1.0 0.9590443028663472
# 0.42857142857142855 1.0 0.07981641386911453
# 0.2 1.0 0.8326284995747257
# 0.42857142857142855 1.0 0.3856378914918941
# 0.2 1.0 0.38603181629669214
# 0.42857142857142855 1.0 0.7116857733794127
# 0.5 1.0 0.8205307990729783
# 0.6666666666666666 1.0 0.036401711849843976
# 0.4 1.0 0.21516275320387424
# 0.6666666666666666 1.0 0.4629379743636439
# 0.5 1.0 0.7153096553155989
# 0.5 1.0 0.3976419535689778
# 0.2 1.0 0.5480162175716312
# 0.42857142857142855 1.0 0.06278794755460038
# 0.2 1.0 0.12794442606480438
# 0.6666666666666666 1.0 0.25402396235736835
# 0.5 1.0 0.012792210511063051
# 0.5 1.0 0.6042298277156369
# 0.5 1.0 0.16548443954521175
# 0.2 1.0 0.27692985851258745
# 0.42857142857142855 1.0 0.09025434668022869
# 0.2 1.0 0.43546455128900396
# 0.42857142857142855 1.0 0.13014968170412478
# 0.2 1.0 0.14562914042355302
# 0.6666666666666666 1.0 0.46661994523594275
# 0.5 1.0 0.3723794932537072
# 0.5 1.0 0.951906927463807
# 0.5 1.0 0.21145964156179065
# 0.2 1.0 0.9336030467161247
# 0.42857142857142855 1.0 0.32535705701233575
# 0.2 1.0 0.7357795994047679
# 0.42857142857142855 1.0 0.23086519478925882
# 0.2 1.0 0.9325389444686573
#
# >> forecast of 42 states
# ['L', 'W', 'L', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W', 'W', 'W', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'L', 'L', 'L', 'W', 'L', 'W', 'L', 'W', 'L', 'W']
# seq-o4 	seq-o5 	count 	prob_of_seq-o5
# LLLL 	 LLLLL 	 1 	 0.5
# LLLL 	 LLLLW 	 1 	 0.5
# LLLW 	 LLLWL 	 2 	 1.0
# LLLW 	 LLLWW 	 0 	 0.0
# LLWL 	 LLWLL 	 0 	 0.0
# LLWL 	 LLWLW 	 2 	 1.0
# LLWW 	 LLWWL 	 2 	 1.0
# LLWW 	 LLWWW 	 0 	 0.0
# LWLL 	 LWLLL 	 1 	 1.0
# LWLL 	 LWLLW 	 0 	 0.0
# LWLW 	 LWLWL 	 1 	 0.25
# LWLW 	 LWLWW 	 3 	 0.75
# LWWL 	 LWWLL 	 0 	 0.0
# LWWL 	 LWWLW 	 3 	 1.0
# LWWW 	 LWWWL 	 2 	 0.667
# LWWW 	 LWWWW 	 1 	 0.333
# WLLL 	 WLLLL 	 1 	 0.5
# WLLL 	 WLLLW 	 1 	 0.5
# WLLW 	 WLLWL 	 0 	 0.0
# WLLW 	 WLLWW 	 1 	 1.0
# WLWL 	 WLWLL 	 1 	 0.333
# WLWL 	 WLWLW 	 2 	 0.667
# WLWW 	 WLWWL 	 1 	 0.25
# WLWW 	 WLWWW 	 3 	 0.75
# WWLL 	 WWLLL 	 1 	 0.5
# WWLL 	 WWLLW 	 1 	 0.5
# WWLW 	 WWLWL 	 2 	 0.667
# WWLW 	 WWLWW 	 1 	 0.333
# WWWL 	 WWWLL 	 2 	 1.0
# WWWL 	 WWWLW 	 0 	 0.0
# WWWW 	 WWWWL 	 0 	 0
# WWWW 	 WWWWW 	 0 	 0
#
# Transition Matrix =
# [[0.5        1.         0.         1.         1.         0.25
#   0.         0.66666667 0.5        0.         0.33333333 0.25
#   0.5        0.66666667 1.         0.        ]
#  [0.5        0.         1.         0.         0.         0.75
#   1.         0.33333333 0.5        1.         0.66666667 0.75
#   0.5        0.33333333 0.         0.        ]]
# 0.0 0.0 0.8036710771830984
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[19], line 16
#      13 # perform multiple simulations
#      14 for _ in range(num_simulations):
#      15     # get the accuracy for this simulation and order
# ---> 16     accuracy = get_prediction_accuracy(seq_train, seq_test, order)
#      18     # append the accuracy to the list of accuracies for this order
#      19     accuracies_for_order.append(accuracy)
#
# Cell In[15], line 31, in get_prediction_accuracy(seq_train, seq_test, order)
#      28         state_next_probs = arr_tr_mat @ state_start
#      30         # based on the probabilities, pick a state
# ---> 31         state_next = pick_state('L', state_next_probs[0], 'W', state_next_probs[1])
#      33 #         print ('predicted state next:', state_next, 'prob(L)=',round(state_next_probs[0], 2))
#      34
#      35         # the next sequence will now include the forecasted state
#      36         # add next state to the current start state, then take only the last n-state sequence to be the next start state
#      37         seq_start = (seq_start + state_next)[-order:]
#
# Cell In[2], line 24, in pick_state(var_a, prob_a, var_b, prob_b)
#      22     return var_b
#      23 else:
# ---> 24     raise Exception("Unexpected error: random number outside [0, 1]")
#
# Exception: Unexpected error: random number outside [0, 1]

# %%
# Q7

# Create a box plot
plt.figure(figsize=(8, 6))
plt.boxplot(results_df['accuracies'], labels=results_df['order'])
plt.xlabel('Order')
plt.ylabel('Accuracy')
plt.title('Box Plot of Accuracy vs Order')
plt.show()

# %% [markdown]
# # Q8
#
# In my opinion, there are some choices of training data that could potentially yield better results:
#
# - Using longer sequences in the training data may capture more complex patterns and dependencies, leading to more accurate predictions. However, longer sequences also increase the complexity of the model and require more computational resources for training.
#
#
# - Implementing cross-validation techniques to evaluate the model's performance on different subsets of the data can identify potential areas for improvement.
